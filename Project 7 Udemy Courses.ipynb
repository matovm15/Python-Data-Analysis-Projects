# %% [markdown]
# # UDEMY COURSES DATASET

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\MATOVU MOSES\Desktop\Data Analysis\7. Udemy Courses.csv')

# %%
data.shape
# Out:
# (3682, 11)

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %% [markdown]
# ### 1. What are all the Subjects for which Udemy is offering Courses?

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# ### 2.  Which Subject has the Maximum number of Courses?

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# ### 3. Show all Courses which are paid or free cost

# %%
data[data.is_paid == False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
data[data.is_paid == True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %% [markdown]
# ### 5. Which are the Top Selling Courses

# %%
data.sort_values('num_subscribers', ascending = False).head(3)
# Out:
#       course_id                          course_title  is_paid price  \
# 2230      41295  Learn HTML5 Programming From Scratch    False  Free
# 776       59014        Coding for Entrepreneurs Basic    False  Free
# 3385     625204            The Web Developer Bootcamp     True   200
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 2230           268923         8629            45      All Levels
# 776            161029          279            27  Beginner Level
# 3385           121584        27445           342      All Levels
#
#      content_duration   published_timestamp          subject
# 2230       10.5 hours  2013-02-14T07:03:41Z  Web Development
# 776         3.5 hours  2013-06-09T15:51:55Z  Web Development
# 3385         43 hours  2015-11-02T21:13:27Z  Web Development

# %% [markdown]
# ### 5. Which are the Least Selling Courses

# %%
data.sort_values('num_subscribers', ascending = True)
# Out:
#       course_id                                       course_title  is_paid  \
# 649     1233314                      Building a Balanced Scorecard     True
# 3259    1232282          The Cash Flow Statement - An Introduction     True
# 3261    1275872                    The Complete Adobe Spark Course     True
# 910      726314       Create Beautiful Image Maps for Your Website     True
# 3328     715476        The Cuckoo Strategy to get European Funding     True
# ...         ...                                                ...      ...
# 3316     764164              The Complete Web Developer Course 2.0     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3385     625204                         The Web Developer Bootcamp     True
# 776       59014                     Coding for Entrepreneurs Basic    False
# 2230      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %% [markdown]
# ### 7. Show all Courses of Graphice Design where price is below 100 ?

# %%
data[(data.subject == 'Graphic Design') & (data.price > '100')]
# Out:
#       course_id                                       course_title  is_paid  \
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20      1165268  15  Motion Graphic Elements in After Effect (S...     True
# 35      1164876  3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True
# 39       599652                     48 Logo Designs and Techniques     True
# 52       794036       8 Stunden professionelles Cinema 4D Training     True
# ...         ...                                                ...      ...
# 3568     133968                 Web Elements Design With Photoshop     True
# 3588    1131780  Whiteboard Animation, Beginner To Expert - In ...     True
# 3639    1122306         Wordpress: Comment utiliser le thème FABLE     True
# 3671     144222  YOU can Draw, Shade and Paint a Mixed Media Gi...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# ### 8. List out all the courses that are related to Python

# %%
len(data[data.course_title.str.contains('Python')])
# Out:
# 29

# %% [markdown]
# ### 9. What the Courses that are published in 2015

# %%
data.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data['published_timestamp'] = pd.to_datetime(data.published_timestamp)

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data['Year'] = data['published_timestamp'].dt.year

# %%
data[data.Year == 2011]
# Out:
#       course_id                                    course_title  is_paid  \
# 431       11475                Become a Certified Web Developer     True
# 447       11174             Become a Web Developer from Scratch     True
# 1743       8325         HTML Tutorial: HTML & CSS for Beginners     True
# 1998       8324                        Javascript for Beginners     True
# 2244      11153  Learn jQuery: An In-depth Course For Beginners     True
#
#      price  num_subscribers  num_reviews  num_lectures       level  \
# 431    100            26673         1090           185  All Levels
# 447    120            69186         2408           197  All Levels
# 1743    20            12458          253            82  All Levels
# 1998    20             3697          195            48  All Levels
# 2244    50             7014           95            62  All Levels
#
#      content_duration       published_timestamp          subject  Year
# ...

# %% [markdown]
# ### 10. What are the Maximum number of subscription for each level of course

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level').max().head(50)
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels             True  Free           268923        27445           544
# Beginner Level         True  Free           161029         5924           779
# Expert Level           True    95             5172          249           157
# Intermediate Level     True  Free            29167         3326           320
#
# ...

# %%
# A Program that prints out name store in variables
name = 'Moses'
age = 22
print("Name: "+name+"\nAge: "+str(age))




# A Program that first and last name of Steve using subString
name = "Steve Smith"
print("First Name: "+ name[0:5])
print("Last Name: "+ name[6:11])
print(name.find("S"))




# A program that prints whether a number is even or odd
num = int(input("Please Enter a number : "))
if num%2==0:
    print("Even Number")
else:
    print("Odd Number")

    
    
    
# A Program that outputs a word for a number between 1 and 5
num = int(input("Enter a number between 1-5 : "))
if num == 1:
    print("one")
elif num == 2:
    print("two")
elif num == 3:
    print("three")
elif num == 4:
    print("four")
elif num == 5:
    print("five")
else:
    print("error")
    
    
    
    

# A program that prints numbers from 1 - 100 divisible by 3 & 5

for i in range(1,101):
    if(i%3 == 0 and i%5==0):

        print(i)
        
        
        
        

# A program that prints number from 1-10 then 10-1

for i in range(1,11):
    print(i)
print("------------------")
for i in range (10,1-1,-1):
    print(i)

"""ALTERNATIVE
  i = 10
while i > 1:
    print(i)
    i -=1
"""  



  

# A program that asks the user for a number and prints the maximum, sum and average
x = 0
sum = 0
while x < 5:
    x += 1
    sum += int(input("Enter a number : "))
print("The sum is : " +str(sum))
print("The Average is : "+str(sum/5))
# Out:
# Enter a number : 1
# Enter a number : 2
# Enter a number : 3
# Enter a number : 4
# Enter a number : 5
# The sum is : 15
# The Average is : 3.0
